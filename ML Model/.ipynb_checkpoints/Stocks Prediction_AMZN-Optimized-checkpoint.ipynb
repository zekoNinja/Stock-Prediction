# %%
# Import our dependencies

from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
# Out:
# WARNING:tensorflow:From D:\Anacondda\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Import our dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf

# %%
# List of tickers
tickers = ['AMZN', 'MSFT', 'AAPL', 'VALE']

# Dictionary to store DataFrames
stock_data = {}

# Loop through each ticker and read the corresponding CSV file
for ticker in tickers:
    ticker_path = Path(f"../Resources/{ticker}.csv")
    stock_data[ticker] = pd.read_csv(ticker_path)
    stock_data[ticker]["Ticker"] = ticker

# Access the DataFrames using the tickers
amzn_stock = stock_data['AMZN']
msft_stock = stock_data['MSFT']
vale_stock = stock_data['VALE']
Apple_stock = stock_data['AAPL']

#Display data for AMZN
print("AMZN Data:")
print(f"MSFT :{len(msft_stock)},\n AMZN:{len(amzn_stock)},\n VALE:{len(vale_stock)},\n AAPL:{len(Apple_stock)} ")
# Out:
# AMZN Data:
# MSFT :522,
#  AMZN:501,
#  VALE:501,
#  AAPL:501

# %%
# %matplotlib inline

# %%
amzn_stock.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-01-03  167.550003  170.703506  166.160507  170.404495  170.404495
# 1  2022-01-04  170.438004  171.399994  166.349503  167.522003  167.522003
# 2  2022-01-05  166.882996  167.126495  164.356995  164.356995  164.356995
# 3  2022-01-06  163.450500  164.800003  161.936996  163.253998  163.253998
# 4  2022-01-07  163.839005  165.243500  162.031006  162.554001  162.554001
#
#      Volume Ticker
# 0  63520000   AMZN
# 1  70726000   AMZN
# 2  64302000   AMZN
# 3  51958000   AMZN
# 4  46606000   AMZN

# %%
#Using the Open Stock Price to be our traing dataset
training_set=amzn_stock.iloc[:1:2].values

training_set
# Out:
# array([[170.703506],
#        [171.399994],
#        [167.126495],
#        [164.800003],
#        [165.2435  ],
#        [161.661499],
#        [166.350006],
#        [166.878006],
#        [166.221497],
#        [162.25    ],
#        [159.734497],
#        [159.25    ],
#        [158.      ],
#        [150.899994],
#        [144.945007],
#        [143.600006],
#        [145.184998],
#        [144.2435  ],
#        [143.998001],
#        [150.360504],
#        [151.707993],
#        [155.074997],
#        [144.247498],
#        [161.199997],
#        [162.690994],
#        [161.792496],
#        [163.834503],
#        [160.716507],
#        [159.      ],
#        [158.448502],
#        [158.007004],
#        [158.834   ],
#        [160.348999],
#        [155.499496],
#        [152.982498],
#        [151.763   ],
#        [151.748993],
#        [153.990005],
#        [154.449997],
#        [154.098999],
#        [152.999496],
#        [153.929001],
#        [147.850006],
# ...

# %%
#Scalling our Dataset/Normailzing the data
scaler = MinMaxScaler (feature_range=(0,1))
scaled_training_set = scaler.fit_transform(training_set)
scaled_training_set
# Out:
# array([[0.99207816],
#        [1.        ],
#        [0.95139332],
#        [0.92493185],
#        [0.92997618],
#        [0.88923458],
#        [0.94256155],
#        [0.94856701],
#        [0.94109989],
#        [0.89592817],
#        [0.8673169 ],
#        [0.86180624],
#        [0.84758877],
#        [0.76683346],
#        [0.69910157],
#        [0.68380356],
#        [0.70183123],
#        [0.69112265],
#        [0.68833035],
#        [0.76069731],
#        [0.77602362],
#        [0.81431985],
#        [0.69116812],
#        [0.88398546],
#        [0.90094403],
#        [0.89072453],
#        [0.91395028],
#        [0.87848626],
#        [0.85896275],
#        [0.85269002],
#        [0.84766843],
#        [0.85707467],
#        [0.87430623],
#        [0.81914809],
#        [0.79051981],
#        [0.77664927],
#        [0.77648996],
#        [0.80197918],
#        [0.80721112],
#        [0.80321887],
#        [0.79071315],
#        [0.80128532],
#        [0.73214297],
# ...

# %%
#Setting up our features and target variables

X_train = []
y_train = []


for i in range(30,501):
    X_train.append(scaled_training_set[i-30:i,0])
    y_train.append(scaled_training_set[i,0])

    

X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
amzn_stock.shape
# Out:
# (501, 8)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (471, 30)
# (471,)

# %%
X_train
# Out:
# array([[0.99207816, 1.        , 0.95139332, ..., 0.87848626, 0.85896275,
#         0.85269002],
#        [1.        , 0.95139332, 0.92493185, ..., 0.85896275, 0.85269002,
#         0.84766843],
#        [0.95139332, 0.92493185, 0.92997618, ..., 0.85269002, 0.84766843,
#         0.85707467],
#        ...,
#        [0.67959508, 0.72543219, 0.72577339, ..., 0.80175165, 0.80607382,
#         0.80186533],
#        [0.72543219, 0.72577339, 0.68061886, ..., 0.80607382, 0.80186533,
#         0.81096455],
#        [0.72577339, 0.68061886, 0.70234303, ..., 0.80186533, 0.81096455,
#         0.8030028 ]])

# %%
y_train
# Out:
# array([0.84766843, 0.85707467, 0.87430623, 0.81914809, 0.79051981,
#        0.77664927, 0.77648996, 0.80197918, 0.80721112, 0.80321887,
#        0.79071315, 0.80128532, 0.73214297, 0.71217586, 0.65081319,
#        0.64570067, 0.74152074, 0.75290044, 0.72759327, 0.7336784 ,
#        0.79242491, 0.84188478, 0.88846678, 0.90541407, 0.94048012,
#        0.9427889 , 0.91718045, 0.93139792, 0.97312911, 0.99353393,
#        0.97213951, 0.94421065, 0.93661285, 0.96581559, 0.96258541,
#        0.89535944, 0.87123521, 0.8404061 , 0.80364546, 0.81459285,
#        0.8251251 , 0.82366933, 0.80254219, 0.8549705 , 0.84306753,
#        0.83323489, 0.75221803, 0.71362034, 0.69808924, 0.66501939,
#        0.71039017, 0.53777302, 0.46847134, 0.48612942, 0.48362149,
#        0.45517518, 0.40457802, 0.34713376, 0.33169361, 0.30341217,
#        0.31051526, 0.33785257, 0.34704845, 0.36760695, 0.33408777,
#        0.30202453, 0.30047774, 0.28820518, 0.24931758, 0.28088037,
# ...

# %%
#Reshaping the dataset
X_train=np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
X_train.shape
# Out:
# (471, 30, 1)

# %%
regressor = Sequential()
regressor
# Out:
# WARNING:tensorflow:From D:\Anacondda\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#Option 1

# Adding Layers into the model 

regressor.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
# regressor.add(Dropout(0.2))
regressor.add(LSTM(units=50,return_sequences=True))
# regressor.add(Dropout(0.2))

# regressor.add(LSTM(units=50,return_sequences=True))
# regressor.add(Dropout(0.2))

# regressor.add(LSTM(units=50))
# regressor.add(Dropout(0.2))
regressor.add(LSTM(50))
regressor.add(Dense(units=1))

# %%
# # Adding Layers into the model
# regressor.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
# regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=50,return_sequences=True))
# regressor.add(Dropout(0.2))
# #regressor.add(LSTM(units=35,return_sequences=True))
# #regressor.add(Dropout(0.2))
# regressor.add(LSTM(units=50))
# #regressor.add(Dropout(0.2))
# regressor.add(Dense(units=1))

# %%
regressor.compile(optimizer='adam',loss='mean_squared_error')
regressor.fit(X_train,y_train,epochs=100,batch_size=64, verbose=1)
# Out:
# WARNING:tensorflow:From D:\Anacondda\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From D:\Anacondda\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 8/8 [==============================] - 10s 33ms/step - loss: 0.1109
# Epoch 2/100
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0287
# Epoch 3/100
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0221
# Epoch 4/100
# 8/8 [==============================] - 0s 59ms/step - loss: 0.0159
# Epoch 5/100
# 8/8 [==============================] - 1s 61ms/step - loss: 0.0134
# Epoch 6/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0119
# Epoch 7/100
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0114
# Epoch 8/100
# ...

# %%
AMZN_ticker_test = Path("../Resources/AMZN _Test.csv")
AMZN_stock_Test = pd.read_csv(AMZN_ticker_test)
AMZN_stock_Test["Ticker"]= "AMZN_Test"  

AMZN_stock_Test.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2024-01-02  151.539993  152.380005  148.389999  149.929993  149.929993
# 1  2024-01-03  149.199997  151.050003  148.330002  148.470001  148.470001
# 2  2024-01-04  145.589996  147.380005  144.050003  144.570007  144.570007
# 3  2024-01-05  144.690002  146.589996  144.529999  145.240005  145.240005
# 4  2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
#
#      Volume     Ticker
# 0  47339400  AMZN_Test
# 1  49425500  AMZN_Test
# 2  56039800  AMZN_Test
# 3  45124800  AMZN_Test
# 4  46757100  AMZN_Test

# %%
#Extracting our 2024 Data for open price
actual_stock_price = AMZN_stock_Test.iloc[:,1:2].values
actual_stock_price
# actual_stock_price.shape
# Out:
# array([[152.380005],
#        [151.050003],
#        [147.380005],
#        [146.589996],
#        [149.399994],
#        [151.710007],
#        [154.419998],
#        [157.169998],
#        [156.199997],
#        [154.990005],
#        [152.149994],
#        [153.779999],
#        [155.759995],
#        [157.050003],
#        [156.210007],
#        [158.509995],
#        [158.509995],
#        [160.720001],
#        [161.289993],
#        [161.729996],
#        [159.009995]])

# %%
#Preping our Data
dataset_total=pd.concat((amzn_stock['Open'],AMZN_stock_Test['Open']),axis  =0)
inputs=dataset_total[len(dataset_total)-len(AMZN_stock_Test)-30:].values

inputs
inputs = inputs.reshape(-1,1)
inputs= scaler.transform(inputs)


X_test = []

for i in range(30,51):
    X_test.append(inputs[i-30:i,0])
X_test= np.array(X_test)
X_test= np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))
X_test

actual_stock_price[1]
# Out:
# array([151.050003])

# %%
X_test[2][-1]
# Out:
# array([0.74749773])

# %%
inputs.shape
# Out:
# (51, 1)

# %%
#Predicting the Values for Jan 2024
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price=scaler.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
#Plotting the Data

plt.plot(actual_stock_price, color ='red', label ="Actual Amazon Open Stock Price")
plt.plot(predicted_stock_price, color ='blue', label ="Predicted Amazon Open Stock Price")
plt.title('Amzn Stock Price Prediction')
plt.xlabel('Time (days)')
plt.ylabel('Amazon Stock Price')
plt.legend()

# %%
predicted_stock_price, actual_stock_price
# Out:
# (array([[153.5798 ],
#         [152.34486],
#         [150.12405],
#         [146.73024],
#         [144.4895 ],
#         [145.30804],
#         [147.51128],
#         [150.86095],
#         [154.27228],
#         [155.82549],
#         [154.7519 ],
#         [152.33755],
#         [151.86891],
#         [153.08948],
#         [155.83904],
#         [156.14606],
#         [157.09991],
#         [157.36398],
#         [158.03827],
#         [159.01643],
#         [160.25568]], dtype=float32),
#  array([[152.380005],
#         [151.050003],
#         [147.380005],
#         [146.589996],
#         [149.399994],
#         [151.710007],
#         [154.419998],
#         [157.169998],
#         [156.199997],
#         [154.990005],
#         [152.149994],
#         [153.779999],
#         [155.759995],
#         [157.050003],
#         [156.210007],
#         [158.509995],
#         [158.509995],
#         [160.720001],
#         [161.289993],
#         [161.729996],
# ...

# %%
AMZN_stock_Test["Predicted Stock Price"] = predicted_stock_price
AMZN_stock_Test
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2024-01-02  151.539993  152.380005  148.389999  149.929993  149.929993
# 1   2024-01-03  149.199997  151.050003  148.330002  148.470001  148.470001
# 2   2024-01-04  145.589996  147.380005  144.050003  144.570007  144.570007
# 3   2024-01-05  144.690002  146.589996  144.529999  145.240005  145.240005
# 4   2024-01-08  146.740005  149.399994  146.149994  149.100006  149.100006
# 5   2024-01-09  148.330002  151.710007  148.210007  151.369995  151.369995
# 6   2024-01-10  152.059998  154.419998  151.880005  153.729996  153.729996
# 7   2024-01-11  155.039993  157.169998  153.119995  155.179993  155.179993
# 8   2024-01-12  155.389999  156.199997  154.009995  154.619995  154.619995
# 9   2024-01-16  153.529999  154.990005  152.149994  153.160004  153.160004
# 10  2024-01-17  151.490005  152.149994  149.910004  151.710007  151.710007
# ...

# %%
predicted_stock_price.shape
# Out:
# (21, 1)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(AMZN_stock_Test["Open"], predicted_stock_price)
mse
# Out:
# 11.707388057506286

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 3.421606064044528
